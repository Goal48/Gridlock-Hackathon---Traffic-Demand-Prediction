# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv("C:\Users\piusd\OneDrive\Desktop\Machine Learning\Flipkart\Gridlock Hackathon - Traffic Demand Prediction\dataset\train.csv")
df.head()
# Out:
#   Cell In[3], line 1
#     df = pd.read_csv("C:\Users\piusd\OneDrive\Desktop\Machine Learning\Flipkart\Gridlock Hackathon - Traffic Demand Prediction\dataset\train.csv")
#                                                                                                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df
